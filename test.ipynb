# %%
import pandas as pd

host_info = pd.read_excel('输入输出表.xlsx', sheet_name=0, usecols='A')
host_info
# Out:
#                 起始IP
# 0     220.178.74.107
# 1     220.178.74.110
# 2     220.178.74.108
# 3     220.178.74.109
# 4    183.162.192.112
# ..               ...
# 498     36.7.173.127
# 499    223.244.92.28
# 500    223.244.92.80
# 501    223.244.92.34
# 502    223.244.92.65
#
# [503 rows x 1 columns]

# %%
ips = host_info.iloc[:, 0].to_list()
ips
# Out:
# ['220.178.74.107',
#  '220.178.74.110',
#  '220.178.74.108',
#  '220.178.74.109',
#  '183.162.192.112',
#  '220.178.73.19',
#  '220.178.73.21',
#  '183.162.192.109',
#  '183.162.192.114',
#  '183.162.192.110',
#  '220.178.73.20',
#  '183.162.192.111',
#  '220.178.73.22',
#  '220.178.73.18',
#  '220.178.75.229',
#  '220.178.75.230',
#  '220.178.75.227',
#  '220.178.75.226',
#  '220.178.81.7',
#  '220.178.81.2',
#  '220.178.81.9',
#  '220.178.81.5',
#  '220.178.81.12',
#  '220.178.81.3',
#  '220.178.81.13',
#  '220.178.81.11',
#  '220.178.81.10',
#  '220.178.81.6',
#  '220.178.81.8',
#  '220.178.82.210',
#  '220.178.82.217',
#  '220.178.82.220',
#  '220.178.82.219',
#  '220.178.82.204',
#  '220.178.82.196',
#  '220.178.82.212',
#  '220.178.82.198',
#  '220.178.82.203',
#  '220.178.82.221',
#  '220.178.82.214',
#  '220.178.82.206',
#  '220.178.82.202',
#  '220.178.82.199',
#  '220.178.82.200',
#  '220.178.82.195',
#  '220.178.82.216',
#  '220.178.82.218',
#  '220.178.82.215',
# ...
